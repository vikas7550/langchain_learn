# %% [markdown]
# ## Basic prompting

# %%
from dotenv import load_dotenv

load_dotenv()
# Out:
# True

# %% [markdown]
# ## Initialising and invoking a model

# %%
from langchain_openrouter import ChatOpenRouter

model = ChatOpenRouter(
    model="nvidia/nemotron-3-super-120b-a12b:free",
    temperature=0.5,
)

# %%
from langchain.agents import create_agent
from langchain.messages import HumanMessage

agent = create_agent(model=model)

question = HumanMessage(content="What's the capital of the moon?")

response = agent.invoke(
    {"messages": [question]}
)

print(response['messages'][1].content)
# Out:
# /Users/vikas4mac/Documents/workspace/agentic_ai/langchain_qs/lca-lc-foundations/.venv/lib/python3.13/site-packages/langgraph/checkpoint/serde/encrypted.py:5: LangChainPendingDeprecationWarning: The default value of `allowed_objects` will change in a future version. Pass an explicit value (e.g., allowed_objects='messages' or allowed_objects='core') to suppress this warning.
#   from langgraph.checkpoint.serde.jsonplus import JsonPlusSerializer
# That's a great question that touches on both space law and common misconceptions! Here's the clear answer:
#
# **The Moon has no capital city — and it cannot have one under current international law.**
#
# ### Why?
# 1. **No Sovereignty**: The Moon is not owned by any nation, group, or individual. The **Outer Space Treaty of 1967** (ratified by 114 countries, including all major spacefaring nations) explicitly states in Article II:
#    > *"Outer space, including the Moon and other celestial bodies, is not subject to national appropriation by claim of sovereignty, by means of use or occupation, or by any other means."*
#    This means no country can claim the Moon as its territory — so there can be no "capital" of a non-existent lunar nation.
#
# 2. **No Permanent Human Settlement**: While humans have landed on the Moon (6 Apollo missions between 1969–1972), we have never established a permanent base or settlement. All visits have been temporary scientific outposts. Current efforts (like NASA's Artemis program) aim for sustainable bases, but these would be **international research stations** — not sovereign territory with a capital.
#
# 3. **Symbols ≠ Ownership**: When astronauts planted flags on the Moon (e.g., the U.S. flag during Apollo 11), it was a symbolic gesture of achievement — **not** a claim of ownership. The treaty explicitly forbids interpreting such acts as territorial claims.
#
# ### What *Could* Happen in the Future?
# If permanent lunar bases are established (e.g., by international consortia like the ISS model), they might have administrative centers or "hubs" for logistics. But these would:
# - Be governed by the agreements of the participating nations/stakeholders (not lunar sovereignty).
# - Likely be referred to as "lunar outposts" or "bases," **not** capitals.
# - Remain subject to the Outer Space Treaty’s principles (no national appropriation).
#
# ### Fun Fact:
# The Moon does have named features (craters, mountains, etc.) governed by the **International Astronomical Union (IAU)**, but these are purely for scientific reference — not political boundaries.
#
# If you're curious about actual lunar exploration, current Artemis mission plans, or how space law governs activities on the Moon, I’d be happy to dive deeper! Just let me know. 🌕

# %%
system_prompt = "You are a science fiction writer, create a capital city at the users request."

scifi_agent = create_agent(
    model=model,
    system_prompt=system_prompt
)

response = scifi_agent.invoke(
    {"messages": [question]}
)

print(response['messages'][1].content)
# Out:
# That's a fun question that touches on both reality and science fiction! Let's break it down:
#
# ### 🌕 The Factual Answer (Right Now)
# **The Moon has no capital city.**
# Why? Because:
# - No nation claims sovereignty over the Moon (per the **1967 Outer Space Treaty**, which governs celestial bodies as "the province of all mankind").
# - There are no permanent human settlements, governments, or cities on the Moon yet—only temporary missions (like Apollo landings or robotic bases).
# - So, politically and legally, the concept of a "capital" doesn't apply.
#
# ### 🚀 The Science Fiction Answer (Where You Come In!)
# As a sci-fi writer, **you get to invent it**—and many great stories have done exactly this! The Moon's capital in fiction often reflects the story's themes: corporate control, scientific utopia, rebel haven, or political struggle. Here are a few iconic examples to spark your imagination:
#
# | **Fictional Work**          | **Lunar Capital**      | **Vibe/Theme**                                  |
# |-----------------------------|------------------------|------------------------------------------------|
# | *The Moon is a Harsh Mistress* (Heinlein) | **Luna City**          | Libertarian colony rebelling against Earth rule |
# | *The Expanse* (TV/Books)    | **Lagrange City** (orbiting, but lunar-adjacent) | Hub for Belt politics & Earth-Mars tension |
# | *Artemis* (Weir)            | **Artemis**            | Tourist-driven, borderline-lawless city under Kenya's "jurisdiction" |
# | *For All Mankind* (TV)      | **Jamestown**          | NASA-led scientific base evolving into a settlement |
# | *Moon* (2009 film)          | **Sarang Base**        | Isolated corporate energy-mining outpost       |
#
# ### 💡 Tips for Creating *Your* Lunar Capital:
# 1. **Purpose Drives Design**:
#    - Is it a **scientific research hub**? (Think clean labs, observatories, low-gravity gardens)
#    - A **mining colony**? (Industrial, rugged, maybe owned by a corporation)
#    - A **political entity**? (Needs government buildings, embassies, maybe a UN-like council)
#    - A **tourist playground**? (Luxury hotels, zero-gravity casinos, Earth-view resorts)
#
# 2. **Location Matters**:
#    - **Near the poles**: Access to water ice (in shadowed craters) for life support/fuel. *Prime real estate.*
#    - **Near the equator**: Easier solar power, but extreme temperature swings.
#    - **Lava tubes**: Natural radiation shielding—great for underground cities!
#
# 3. **Culture & Conflict**:
#    - How do low gravity (1/6th G) and isolation shape society?
#    - Ties to Earth: Dependent? Independent? A refuge?
#    - Unique slang, traditions, or even physiology (long-term low-G effects?).
#
# 4. **Name Ideas**:
#    - **Descriptive**: *Selene Port*, *Crateris*, *Tranquility Gateway*
#    - **Mythological**: *Artemis Base*, *Thalassa* (Greek sea moon goddess), *Chang'e* (Chinese moon goddess)
#    - **Corporate**: *Helios Dome*, *LunaCorp Central*
#    - **Evocative**: *New Hope*, *Edge of Silence*, *Stellaris*
#
# ### 🌟 Your Turn!
# If you'd like, **share a bit about your story’s tone or themes**, and I’ll help you brainstorm a specific lunar capital—complete with name, layout, culture, and a juicy political/sci-fi twist. For example:
# > *"I’m writing a noir detective story set 100 years after the Moon declares independence. The capital should feel gritty, with corporate spies and old Earth diplomats lurking in the shadows..."*
#
# Just say the word—I’d love to co-create your lunar world with you! 🌕✨

# %% [markdown]
# ## Few-shot examples

# %%
system_prompt = """

You are a science fiction writer, create a space capital city at the users request.

User: What is the capital of mars?
Scifi Writer: Marsialis

User: What is the capital of Venus?
Scifi Writer: Venusovia

"""

scifi_agent = create_agent(
    model=model,
    system_prompt=system_prompt
)

response = scifi_agent.invoke(
    {"messages": [question]}
)

print(response['messages'][1].content)
# Out:
# Scifi Writer: Lunaris
#
# *(Following the pattern: Mars → Marsialis [Mars + -ialis], Venus → Venusovia [Venus + -ovia], so Luna → Lunaris [Luna + -ialis]. The suffix "-ialis" evokes a classical, administrative feel—like a provincial or civic designation—common in sci-fi worldbuilding for settled celestial bodies.)*

# %% [markdown]
# ## Structured prompts

# %%
system_prompt = """

You are a science fiction writer, create a space capital city at the users request.

Please keep to the below structure.

Name: The name of the capital city

Location: Where it is based

Vibe: 2-3 words to describe its vibe

Economy: Main industries

"""

scifi_agent = create_agent(
    model=model,
    system_prompt=system_prompt
)

response = scifi_agent.invoke(
    {"messages": [question]}
)

print(response['messages'][1].content)
# Out:
# Name: **Lunar Nexus**
# Location: **Shackleton Crater, Lunar South Pole** (chosen for near-permanent sunlight access for power and proximity to water ice deposits)
# Vibe: **Hopeful, gritty, innovative**
# Economy: **Helium-3 fusion fuel extraction, regolith-based manufacturing, and lunar tourism/hospitality**
#
# *Note: In reality, the Moon has no sovereign nation or official capital. This is a scientifically grounded sci-fi concept for a future lunar settlement, reflecting current Artemis program interests in the South Pole.*

# %% [markdown]
# ## Structured output

# %%
from langchain.agents import create_agent
from langchain.messages import HumanMessage
from pydantic import BaseModel

class CapitalInfo(BaseModel):
    name: str
    location: str
    vibe: str
    economy: str

agent = create_agent(
    model= model,
    system_prompt="You are a science fiction writer, create a capital city at the users request.",
    response_format=CapitalInfo
)

question = HumanMessage(content="What is the capital of The Moon?")

response = agent.invoke(
    {"messages": [question]}
)

response["structured_response"]
# Out:
# CapitalInfo(name='Artemis Prime', location='Lunar South Pole, Shackleton Crater', vibe='Futuristic, international cooperation, scientific hub', economy='Helium-3 mining, space tourism, and research')

# %%
print(response["structured_response"])
# Out:
# name='Artemis Prime' location='Lunar South Pole, Shackleton Crater' vibe='Futuristic, international cooperation, scientific hub' economy='Helium-3 mining, space tourism, and research'

# %%
capital_info = response["structured_response"]

capital_name = capital_info.name
capital_location = capital_info.location

print(f"{capital_name} is a city located at {capital_location}")
# Out:
# Artemis Prime is a city located at Lunar South Pole, Shackleton Crater
