# %%
from dotenv import load_dotenv

load_dotenv()
# Out:
# True

# %%
from langchain.tools import tool
from typing import Dict, Any
from tavily import TavilyClient

tavily_client = TavilyClient()

@tool
def web_search(query: str) -> Dict[str, Any]:

    """Search the web for information"""

    return tavily_client.search(query)
# Out:
# /Users/vikas4mac/Documents/workspace/agentic_ai/langchain_qs/lca-lc-foundations/.venv/lib/python3.13/site-packages/langgraph/checkpoint/serde/encrypted.py:5: LangChainPendingDeprecationWarning: The default value of `allowed_objects` will change in a future version. Pass an explicit value (e.g., allowed_objects='messages' or allowed_objects='core') to suppress this warning.
#   from langgraph.checkpoint.serde.jsonplus import JsonPlusSerializer

# %%
system_prompt = """

You are a personal chef. The user will give you a list of ingredients they have left over in their house.

Using the web search tool, search the web for recipes that can be made with the ingredients they have.

Return recipe suggestions and eventually the recipe instructions to the user, if requested.

"""

# %%
from langchain_openrouter import ChatOpenRouter

model = ChatOpenRouter(
    model="nvidia/nemotron-3-super-120b-a12b:free",
    temperature=0.1,
)

# %%
from langchain.agents import create_agent
from langgraph.checkpoint.memory import InMemorySaver

agent = create_agent(
    model=model,
    tools=[web_search],
    system_prompt=system_prompt,
    checkpointer=InMemorySaver()
)

# %%
from langchain.messages import HumanMessage

config = {"configurable": {"thread_id": "1"}}

response = agent.invoke(
    {"messages": [HumanMessage(content="I have some leftover rice raw onions, tomatoes, green chilli and soya chunks. What can I make?")]},
    config
)

print(response['messages'][-1].content)
# Out:
# Based on your ingredients—leftover rice, raw onions, tomatoes, green chilies, and soya chunks—you can make a delicious, protein-packed one-pot meal. Here’s a simple and flavorful **Soya Chunks Pulao (using leftover rice)** that comes together quickly.
#
# ---
#
# ### 🍚 **Soya Chunks Pulao (Leftover Rice Version)**
#
# **Ingredients**
# - Leftover cooked rice – about 2 cups (preferably day-old, as it fries better)
# - Soya chunks (meal maker/nutrela) – 1 cup
# - Onion – 1 large, thinly sliced
# - Tomatoes – 2 medium, chopped
# - Green chilies – 2–3, slit lengthwise
# - Ginger-garlic paste – 1 tsp *(optional, if you have it)*
# - Oil or ghee – 2–3 tablespoons
# - Whole spices (optional but recommended):
#   - Cumin seeds – 1 tsp
#   - Bay leaf – 1
#   - Cinnamon stick – small piece
#   - Cloves – 2–3
#   - Green cardamom – 2
# - Ground spices:
#   - Turmeric powder – ½ tsp
#   - Red chili powder – ½–1 tsp (adjust to taste)
#   - Coriander powder – 1 tsp
#   - Garam masala – ½ tsp
# - Salt – to taste
# - Fresh coriander leaves – a handful, chopped (for garnish, optional)
#
# **Steps**
#
# 1. **Prepare the soya chunks:**
#    Place the soya chunks in a bowl and cover with hot water. Let them soak for 15–20 minutes until soft. Drain, squeeze out excess water, and set aside. (You can lightly crumble them if you prefer smaller pieces.)
#
# 2. **Temper the whole spices:**
#    Heat oil or ghee in a wide pan, kadai, or skillet over medium heat. Add cumin seeds, bay leaf, cinnamon, cloves, and cardamom. Sauté for 10–15 seconds until fragrant.
#
# 3. **Sauté the aromatics:**
#    Add the sliced onions and cook until they turn translucent and start to golden at the edges (about 3–4 minutes).
#    If using ginger-garlic paste, add it now and sauté for another minute until the raw smell disappears.
#
# 4. **Add chilies and tomatoes:**
#    Stir in the slit green chilies and chopped tomatoes. Cook, stirring occasionally, until the tomatoes break down and become soft and mushy (about 4–5 minutes).
#
# 5. **Season with spices:**
#    Add turmeric powder, red chili powder, coriander powder, garam masala, and salt. Mix well and cook for 1 minute, allowing the spices to release their aroma and the oil to start separating from the masala.
#
# 6. **Add the soya chunks:**
#    Add the soaked and squeezed soya chunks. Toss to coat them evenly with the masala. Sauté for 2–3 minutes so they absorb the flavors.
#
# 7. **Incorporate the leftover rice:**
#    Gently break up any clumps in the leftover rice and add it to the pan. Toss everything together carefully, ensuring the rice is evenly coated with the masala and mixed with the onions, tomatoes, and soya chunks.
#    *Tip:* If the rice seems dry, sprinkle a tablespoon of water or a few drops of oil to help it loosen up.
#
# 8. **Finish and serve:**
#    Cook on low heat for another 2–3 minutes, stirring occasionally, until everything is heated through. Taste and adjust salt or spices if needed.
#    Garnish with chopped fresh coriander leaves (if available) and serve hot.
#
# **Serving suggestion:** Enjoy it as is, or pair with a side of plain yogurt, raita, or a simple cucumber-onion salad.
#
# ---
#
# ### 💡 **Variations & Tips**
# - **No whole spices?** Skip them—just start with oil, add onions, then proceed with the ginger-garlic paste (if using), chilies, tomatoes, and ground spices.
# - **No ginger-garlic paste?** You can finely chop a small piece of ginger and a garlic clove (if you have them) and sauté with the onions, or simply omit them—the dish will still be tasty.
# - **Add veggies:** If you have any other veggies (peas, carrots, bell peppers), sauté them with the onions for extra nutrition and color.
# - **Make it tangy:** A squeeze of lemon juice at the end brightens the flavors.
# - **For a saucier version:** Add ¼–½ cup water or tomato puree with the tomatoes and let it simmer a bit before adding the rice—this creates a slightly moist pulao-style dish.
#
# ### 🍛 **Other Ideas with Your Ingredients**
# - **Soya Chunks Curry (Masala):** Make a spicy tomato-onion gravy with the soaked soya chunks and serve it over your leftover rice.
# - **Soya Chunks Fried Rice (Indo-Chinese style):** Sauté soya chunks with soy sauce, chili sauce, and vinegar (if you have them), then toss with onions, chilies, and leftover rice.
# - **Tomato Rice with Soya Chunks:** Cook the soya chunks with tomatoes, onions, and spices, then mix with rice for a tangy, colorful dish.
#
# Let me know if you’d like a detailed recipe for any of these variations, or if you have other ingredients on hand (like ginger, garlic, soy sauce, etc.) that we can incorporate!

# %%
from pprint import pprint


pprint(response["messages"][2].content)
# Out:
# ('{"query": "leftover rice soya chunks onions tomatoes green chili recipe", '
#  '"follow_up_questions": null, "answer": null, "images": [], "results": '
#  '[{"title": "Soya Granules Pulao-Granules from Soya Chunks", "url": '
#  '"https://hungrypalate.com/soya-granules-pulao-granules-from-soya-chunks", '
#  '"content": "June 17, 2021 - Wash Basmati rice thoroughly and soak it for 30 '
#  'minutes. After 30 Minutes drain and keep aside. Place in the colander so '
#  'that the water is drained completely. Meanwhile, finely chop half the Onion '
#  'and keep it aside. Then julienne or chop the remaining onion into '
#  'lengthwise. Finely chop the tomatoes, and slit the green chillies and keep '
#  'them aside.", "score": 0.8047902, "raw_content": null}, {"title": "Soya Rice '
#  'Recipe: How to make Soya Rice Recipe at Home | Homemade Soya Rice Recipe '
#  '-Times Food", "url": '
#  '"https://recipes.timesofindia.com/recipes/soya-rice/rs56981684.cms", '
#  '"content": "February 5, 2017 - Next, in a pan heat some ghee and add the '
#  'cumin seeds and cloves to it. Then, add the onions, tomatoes, green '
#  'chillies, cinnamon stick, and bay leaves. Add the peas to the pan. Cook them '
#  'for a few minutes. Drain the water from the soya chunks, squeeze out excess '
#  'water and add them to the pan. Time 40:00 Calories 346", "score": 0.7760977, '
#  '"raw_content": null}, {"title": "Soya Manchurian Recipe | Soya Chunks Chilli '
#  '- Cook with Kushi", "url": '
#  '"https://www.cookwithkushi.com/soya-manchurian-soya-chunks-chilli-recipe", '
#  '"content": "April 17, 2024 - 1 tablespoon Ginger, 2 tablespoon Onions, 2 '
#  'tablespoon Green onions, ½ tablespoon Green chile · Add chili sauce, soya '
#  'sauce, vinegar, ketchup, chile powder, and cilantro and mix until combined '
#  'on high flame . 5.0 (19) Time 30:00 Calories 219", "score": 0.6821721, '
#  '"raw_content": null}, {"title": "Soya Chunks Manchurian – My Plantiful '
#  'Cooking", "url": '
#  '"https://www.myplantifulcooking.com/soya-chunks-manchurian", "content": "It '
#  'is incredibly flavorful and saucy and goes well with many dishes. I love '
#  'serving it with rice dishes like chickpea pulao and tofu fried rice. * '
#  'Healthier and lower in fats - soya chunks are pan-fried instead of fried! '
#  'The fried ingredients are then cooked in a savory and flavorful sauce made '
#  'from soy sauce, garlic, ginger, and chilies, along with other aromatics and '
#  'seasonings. It is highly versatile and is commonly served as an appetizer or '
#  'side to accompany rice or noodle dishes. This vegetarian version of '
#  'Manchurian is made from soya chunks instead of chicken. Rehydrate soya '
#  'chunks by simmering them in water for 3-4 minutes. Drain and rinse them in '
#  'water for 2-3 times, gently squeezing the soya chunks to remove excess water '
#  'after every rinse. Top with chopped green onion, and your soya chunks '
#  'Manchurian is ready to be served! * A plate of Manchurian fried rice served '
#  'with chopsticks with chopped green onion and soy sauce beside.", "score": '
#  '0.5832277, "raw_content": null}, {"title": "Bhaatukli: Tomato Rice with Soya '
#  'Chunks", "url": '
#  '"http://bhaatukli.blogspot.com/2007/06/tomato-rice-with-protein-boost.html", '
#  '"content": "Ingredients: (serves 2) Basmati ... 1 tsp Salt as per taste Oil '
#  '1 tbsp Water 2 1/2 cups Method: Soak the Soya chunks in water for at least '
#  '20 -25 minutes .", "score": 0.55391616, "raw_content": null}], '
#  '"response_time": 3.41, "request_id": "35a65a2a-2028-445c-8a9a-aad9977664bc"}')
